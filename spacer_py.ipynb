# %% [markdown]
# <a href="https://colab.research.google.com/github/viktor-chiarcos/Colab/blob/main/spacer_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Wichtige Fragen (Bitte sofort ausführen)
vcghioqz = input('Wurdest du von viktor-chiarcos.github.io hier hin geleitet? (Antworten mit J oder N)  ')
if vcghioqz == 'J':
    print('Super!') # Indented this line to be part of the if statement block

if vcghioqz == 'N':
    print('Schade!')
    print('du darfst gerne wieder zurück gehen')
    print('Dies ist eine page auf viktor-chiarcos.github.io')
    print('Bis Bald!')
selbst = input('Wolltest du selber zu dieser Seite kommen? (Antworten mit J und N) ')
if selbst == 'J':
    print('SUPER!!!!')
    print('Viel Spaß bei dem ViktorChatBot')
if selbst == 'N':
  print('Schade!')
  print('du darfst gerne wieder zurück gehen')
  print('Dies ist eine page auf viktor-chiarcos.github.io')
  print('Bis Bald!')
# Out:
# Wurdest du von viktor-chiarcos.github.io hier hin geleitet? (Antworten mit J oder N)  J
# Super!
# Wolltest du selber zu dieser Seite kommen? (Antworten mit J und N) J
# SUPER!!!!
# Viel Spaß bei dem ViktorChatBot

# %% [markdown]
# ![IMG_1212.jpeg](data:image/jpeg;base64,...)

# %%
# @title  Version 1.1.00
print('Wilkommen bei dem Viktor ChatBot')
print('Wilkommen bei Python3')
print('Python3 auf Google Colab')
print('Wie heißt du?')
name = input('Name: ')
print('Hallo ', name)
print('')
print('Wie alt bist du?')
alter = input('Alter: ')
print('Ok, verstehe')
print('')
print('Bis Bald!')
# Out:
# Wilkommen bei dem Viktor ChatBot
# Wilkommen bei Python3
# Python3 auf Google Colab
# Wie heißt du?
# Name: Viktor
# Hallo  Viktor
#
# Wie alt bist du?
# Alter: 9
# Ok, verstehe
#
# Bis Bald!

# %% [markdown]
# **Version 1.1.00**
#
# Die Hauptidee vom spacer
#
# Die erste version

# %%
# @title Version 1.1.01
print('Hallo')
print('Version Nr. 2')
print('Bitte sage deinen Namen!')
name = input('Dein Name: ')
print('Und wie alt bist du?')
alter = input('Dein Alter: ')
print('SUPER! ICH VERSTEHE')
print('Wie oft hasgt du heute Zähne geputzt?')
zputzen = input('Die Anzahl an diesem Tag: ')
print('Bis Bald!')

# %% [markdown]
# **Version 1.1.01**
#
# Die Version die den spacer anders Benutzt
#
# Die zweite Version

# %%
# @title Version 1.1.02
vorname = input('Vorname: ')
nachname = input('Nachname: ')
print('')
zaehneputzen = input('Anzahl Zähne putzen: ')

# %% [markdown]
# ![IMG_1213.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Version 1.1.02**
#
# Das ist eine Version die eine Zusammensetzung vorbereitet
#
# Die dritte Version

# %%
# @title Version 1.2.00
print('Wie heißt du?')
vorname = input('Vorname: ')
nachname = input('Nachname: ')
print('Hallo', vorname, nachname)
print('Welches Datum ist Heute?')
datum = input('Datum: ')
print('Hast du am ', datum,' Zähne geputzt?')
zputzen = input('JA/NEIN: ')
print('Wie oft?')
azputzen = input('Zahl: ')
print('OK!')
print('Bis Bald!')

# %% [markdown]
# **Version 1.2.00**
#
# Das Update mit Hilfe von *Version 1.1.02*
#
# Die erste version

# %%
# @title Version 1.2.01
name = input('Bitte sage mir deinen Vornamen: ')
name2 = input('Bitte sage mir deinen Nachnamen: ')
zaehneputzen = input('Bitte sage mir die Anzahl vom Zähne putzen Heute: ')
datum = input('Bitte sage mir das Heutige Datum: ')
uhrzeit = input('Bitte sage mir die Aktuelle Uhrzeit: ')

# %% [markdown]
# ***Version 1.2.01***
#
# Die Version die keine Fragen stellt sondern Anliegen hat

# %%
# @title Version 1.2.02
name = input('Vorname: ')
name2 = input('Nachname: ')
print('Hallo', name, name2)
zaehneputzen = input('Anzahl Zähne Putzen Heute: ')
datum = input('Datum: ')
print('Ok, Heute ist der ',datum)
uhrzeit = input('Uhrzeit: ')
print('Ok, Jetzt ist ',uhrzeit,'Uhr')
# Out:
# Vorname: Olga
# Nachname: Chiarcos
# Hallo Olga  Chiarcos
# Anzahl Zähne Putzen Heute: 1
# Datum: 14.2.25
# Ok, Heute ist der  14.2.25
# Uhrzeit: 21:05
# Ok, Jetzt ist  21:05 Uhr

# %% [markdown]
# # Info über *Version 1.2.02*
#
# Das ist die Version die gleich ist wie *Version 1.2.02* aber nur mit Antworten

# %%
# @title Version 1.2.03
print('Viktor Chatbot fragt wie du heißt')
name = input('     ')
print('Viktor Chatbot fragt wie viel Uhr es ist')
uhr = input('      ')
# Out:
# Viktor Chatbot fragt wie du heißt
#      Viktor
# Viktor Chatbot fragt wie viel Uhr es ist
#       14:04

# %% [markdown]
# # Info über *Version 1.2.03*
#
# Vorbereitung auf Version 1.3.00

# %% [markdown]
# ![IMG_1214.jpeg](data:image/jpeg;base64,...)

# %%
# @title Version 1.3.00
print('Viktor ChatBot fragt wie du heißt')
name = input('      ')
name2 = input('      ')
print('Hallo',name , name2)
print('Viktor ChatBot will wissen wie viel Uhr es ist')
uhr = input('       ')
print('Viktor ChatBot will wissen welches Datum Heute ist')
data = input('       ')
print('Danke!')
print('Heute ist der ', data,'um',uhr)
# Out:
# Viktor ChatBot fragt wie du heißt
#       Viktor
#       Chiarcos
# Hallo Viktor Chiarcos
# Viktor ChatBot will wissen wie viel Uhr es ist
#        14:39
# Viktor ChatBot will wissen welches Datum Heute ist
#        15.2.25
# Danke!
# Heute ist der  15.2.25 um 14:39

# %% [markdown]
# # Info über *Version 1.3.00*
#
# Das ist die Version die mit *Version 1.2.03* vorbereitet wurde
#
# Die erste Version

# %%
# @title Version 1.3.01
name = input('Viktor Chatbot will wissen wie du heißt  ')
name2 = input('                                         ')
uhrzeit = input('Viktor ChatBot will wissen wie viel uhr es ist  ')
data = input('Viktor ChatBot will wissen welches datum heute ist  ')
print('Danke für alles:')
print('Viktor ChatBot will wissen wie du heißt: '+ name)
print('                                       : ' + name2)
print('Viktor ChatBot will wissen wie viel uhr es ist: '+ uhrzeit)
print('Viktor ChatBot will wissen welches datum heute ist: '+ data)
# Out:
# Viktor Chatbot will wissen wie du heißt  Tim
#                                          Rybkin

# %% [markdown]
# # Info über *Version 1.3.01*
#
# - Version 2
# - Bearbeitet

# %%
# @title Uhrzeitkonferenz (Version 1.3.02)
# @title Version 1.3.02
from time import asctime
print('Hallo, wie heißt du?')
name = input('Name: ')
print('Lass mich raten: ', asctime())
time = input('Ist das Richtig?: ')
# Out:
# Hallo, wie heißt du?
# Name: Viktor
# Lass mich raten:  Sun Feb 16 10:29:56 2025
# Ist das Richtig?: Ja

# %% [markdown]
# # Info über diese coole Version
# # Uhrzeitkonferenz
# # Version 1.3.02
#
# Dies ist eine Uhrzeitkonferenz weil der Befehl
#
# ```
# asctime())
# ```
# eingefallen ist
#
# aber dann hat Colab mich verbessert und ich habe:
#
#     from time import asctime
#     asctime())
# geschrieben

# %% [markdown]
# ![Verrsion-2.1.png](data:image/png;base64,...)

# %%
# @title Version 2.1.00
from time import asctime
print('time:',asctime())
name = input('Viktor ChatBot will wissen wie du heißt: ')
name2 = input('                                         ')
uhrzeitdatactrl = input('Viktor ChatBot will wissen ob er die Aktuelle Zeit richtig geschrieben hat: ')
print('Danke für alles:')
print('Viktor ChatBot will wissen wie du heißt: '+ name)
print('                                       : ' + name2)
print('Viktor ChatBot will wissen ob er die Aktuelle Zeit richtig geschrieben hat:',uhrzeitdatactrl)
# Out:
# time: Sun Feb 16 11:11:50 2025
# Viktor ChatBot will wissen wie du heißt: Yannick
#                                          Günter
# Viktor ChatBot will wissen ob er die Aktuelle Zeit richtig geschrieben hat: JA
# Danke für alles:
# Viktor ChatBot will wissen wie du heißt: Yannick
#                                        : Günter
# Viktor ChatBot will wissen ob er die Aktuelle Zeit richtig geschrieben hat: JA

# %% [markdown]
# **Version 2.1.00**
#
# Version erstellt aus *Version 1.1.02*

# %%
# @title # Das Zahlenratenspiel (***Version 2.1.01***)
from random import randint
zufallszahl = randint(1, 80)
print('Ich denke mir eine Zahl zwischen 1 und 80.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
# Out:
# Ich denke mir eine Zahl zwischen 1 und 80.
# Rate mal, welche zahl das ist
# Deine Vermutung:  20
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  10
# Zu kleine Zahl
# Bitte versuche es noch einmal

# %% [markdown]
# **Version 2.1.01**
# # **Das Zahlenratenspiel**
#
# Ich habe dieses Spiel auf meinem Computer erfunden und habe es jetzt auch auf Colab

# %% [markdown]
# # Version Zahlenspiele

# %%
# @title # **Zahlenspiele Version 1**
from random import randint
zufallszahl = randint(1, 20)
print('Ich denke mir eine Zahl zwischen 1 und 20.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
if einfach == 'N':
  print('Tut mir leid!')
  print('Das ist die allererste Version!')
  print('Versuche es einfach noch ein mal!')
  print('Es sollte doch nicht zu einfach werden!')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 1 und 20.
# Rate mal, welche zahl das ist
# Deine Vermutung:  10
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  5
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  2
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  1
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  3
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      M
# Dann Probiere die vorherige Version
#              oder:
# Wiederhole die Version nochmal
#              oder:
# Versuche sogar die nächste!

# %% [markdown]
# # **Zahlenspiele Version 1**
#
# - Von 1-20
# - Einfach
# - Level 1
# - Aller Erste und Einfachste Version von allen

# %%
# @title # **Zahlenspiele Version 2**
from random import randint
zufallszahl = randint(1, 50)
print('Ich denke mir eine Zahl zwischen 1 und 50.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 1 und 50.
# Rate mal, welche zahl das ist
# Deine Vermutung:  20
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  10
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  0
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  1
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  2
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  4
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  8
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  9
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit J und N)      J
# Dann Probiere dich nächste Version

# %% [markdown]
# # **Zahlenspiele Version 2**
#
# - Noch leicht
# - Schwerer
# - Level 2

# %%
# @title # **Zahlenspiele Version 3**
from random import randint
zufallszahl = randint(1, 80)
print('Ich denke mir eine Zahl zwischen 1 und 80.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 1 und 80.
# Rate mal, welche zahl das ist
# Deine Vermutung:  1
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  5
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  50
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  70
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  60
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  65
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  63
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      M
# Dann Probiere die vorherige Version
#              oder:
# Wiederhole die Version nochmal
#              oder:
# Versuche sogar die nächste!

# %% [markdown]
# # **Zahlenspiele  Version 3**
# - Noch einfach
# - Level 3
# - von 1 bis 80

# %%
# @title # **Zahlenspiele Version 4**
from random import randint
zufallszahl = randint(1, 100)
print('Ich denke mir eine Zahl zwischen 1 und 100.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 1 und 100.
# Rate mal, welche zahl das ist
# Deine Vermutung:  50
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  60
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  80
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  90
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  8
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  88
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  85
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  86
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      J
# Dann Probiere dich nächste Version

# %% [markdown]
# # **Zahlenspiele Version 4**
# - Schwer
# - Level 4
# - von 1 bis 100

# %%
# @title # **Zahlenspiele Version 5**
from random import randint
zufallszahl = randint(10, 120)
print('Ich denke mir eine Zahl zwischen 10 und 120.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
  print('           Oder:')
  print('Probiere diese Version noch ein mal')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 10 und 120.
# Rate mal, welche zahl das ist
# Deine Vermutung:  100
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  1
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  4
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  30
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  20
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  25
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      J
# Dann Probiere dich nächste Version

# %% [markdown]
# # **Zahlenspiel Version  5**
# - Ungewöhnlich
# - von 1 bis 110 (von 10 bis 120)
# - Konzentration
# - Level 5
# - Schwer

# %%
# @title # **Zahlenspiele Version 6**
from random import randint
zufallszahl = randint(100, 250)
print('Ich denke mir eine Zahl zwischen 100 und 250.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere dich nächste Version')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 100 und 250.
# Rate mal, welche zahl das ist
# Deine Vermutung:  150
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  190
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  200
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      J
# Dann Probiere dich nächste Version

# %% [markdown]
#  **Zahlenspiel Version 6**
#  - Kompliziert
#  - von 1 bis 150 (Von 100 bis 250)
#  - Schwer
#  - Level 6

# %%
# @title # **Zahlenspiele Version 7**
from random import randint
zufallszahl = randint(500, 660)
print('Ich denke mir eine Zahl zwischen 500 und 660.')
print('Rate mal, welche zahl das ist')
zahl = int(input('Deine Vermutung:  '))
while zahl != zufallszahl:
    if zahl < zufallszahl:
        print('Zu kleine Zahl')
        print('Bitte versuche es noch einmal')
    else:
        print('Zu große Zahl')
        print('Bitte versuche es noch ein mal')
    zahl = int(input('Deine Vermutung:  '))
print('SUPER')
print('Mache das gleich noch ein mal!')
einfach = input('War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      ')
if einfach == 'J':
  print('Dann Probiere die nächste Version')
if einfach == 'N':
  print('Dann Probiere die vorherige Version')
if einfach == 'M':
  print('Dann Probiere die vorherige Version')
  print('             oder:')
  print('Wiederhole die Version nochmal')
  print('             oder:')
  print('Versuche sogar die nächste!')
# Out:
# Ich denke mir eine Zahl zwischen 500 und 660.
# Rate mal, welche zahl das ist
# Deine Vermutung:  500
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  660
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  510
# Zu große Zahl
# Bitte versuche es noch ein mal
# Deine Vermutung:  505
# Zu kleine Zahl
# Bitte versuche es noch einmal
# Deine Vermutung:  506
# SUPER
# Mache das gleich noch ein mal!
# War das Noch einfach genug? (Antworten mit [J für Ja] und [N für Nein] und [M für Mittel])      J
# Dann Probiere dich nächste Version

# %% [markdown]
# # **Zahlenspiele Version 7**
# - Ganz schwer
# - von 1 bis 160 (Von 500 bis 660)
# - Level 7
